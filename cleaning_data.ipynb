# %%
import pandas as pd

# %%
#com
df_uber=pd.read_csv("data/uber-raw-data-janjune-15.csv")

# %%
df_uber.head()
# Out:
#   Dispatching_base_num          Pickup_date Affiliated_base_num  locationID
# 0               B02617  2015-05-17 09:47:00              B02617         141
# 1               B02617  2015-05-17 09:47:00              B02617          65
# 2               B02617  2015-05-17 09:47:00              B02617         100
# 3               B02617  2015-05-17 09:47:00              B02774          80
# 4               B02617  2015-05-17 09:47:00              B02617          90

# %%
df_uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14270479 entries, 0 to 14270478
# Data columns (total 4 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Dispatching_base_num  object
#  1   Pickup_date           object
#  2   Affiliated_base_num   object
#  3   locationID            int64
# dtypes: int64(1), object(3)
# memory usage: 435.5+ MB

# %%
df_uber['cab_type']='Uber'

# %%
df_uber.head()
# Out:
#   Dispatching_base_num          Pickup_date Affiliated_base_num  locationID  \
# 0               B02617  2015-05-17 09:47:00              B02617         141
# 1               B02617  2015-05-17 09:47:00              B02617          65
# 2               B02617  2015-05-17 09:47:00              B02617         100
# 3               B02617  2015-05-17 09:47:00              B02774          80
# 4               B02617  2015-05-17 09:47:00              B02617          90
#
#   cab_type
# 0     Uber
# 1     Uber
# 2     Uber
# 3     Uber
# 4     Uber

# %%
df_uber['Pickup_date'] = pd.to_datetime(df_uber['Pickup_date'])
df_uber.dtypes
df_uber.head()
# Out:
#   Dispatching_base_num         Pickup_date Affiliated_base_num  locationID  \
# 0               B02617 2015-05-17 09:47:00              B02617         141
# 1               B02617 2015-05-17 09:47:00              B02617          65
# 2               B02617 2015-05-17 09:47:00              B02617         100
# 3               B02617 2015-05-17 09:47:00              B02774          80
# 4               B02617 2015-05-17 09:47:00              B02617          90
#
#   cab_type
# 0     Uber
# 1     Uber
# 2     Uber
# 3     Uber
# 4     Uber

# %%
import datetime

def get_hours(x:pd.Series)->pd.Series:
    x=x.apply(lambda x:x.hour)
    return x

def get_day_of_month(x:pd.Series)->pd.Series:
    x=x.apply(lambda x:x.day)
    return x

def get_day_of_week(x:pd.Series)->pd.Series:
    x=x.apply(lambda x:x.weekday())
    return x

def get_day_of_week_name(x:pd.Series)->pd.Series:
    x=x.apply(lambda x:x.strftime('%A'))
    return x

# %%
'''
df_uber['day_of_week']=get_hours(df_uber['Pickup_date'])
df_uber['day_of_month']=get_day_of_month(df_uber['Pickup_date'])
df_uber['day_of_week']=get_day_of_week(df_uber['Pickup_date'])
df_uber['day_of_week_name']=get_day_of_week_name(df_uber['Pickup_date'])
'''
# Out:
# "\ndf_uber['day_of_week']=get_hours(df_uber['Pickup_date'])\ndf_uber['day_of_month']=get_day_of_month(df_uber['Pickup_date'])\ndf_uber['day_of_week']=get_day_of_week(df_uber['Pickup_date'])\ndf_uber['day_of_week_name']=get_day_of_week_name(df_uber['Pickup_date'])\n"

# %%
df_uber.head(20)
# Out:
#    Dispatching_base_num         Pickup_date Affiliated_base_num  locationID  \
# 0                B02617 2015-05-17 09:47:00              B02617         141
# 1                B02617 2015-05-17 09:47:00              B02617          65
# 2                B02617 2015-05-17 09:47:00              B02617         100
# 3                B02617 2015-05-17 09:47:00              B02774          80
# 4                B02617 2015-05-17 09:47:00              B02617          90
# 5                B02617 2015-05-17 09:47:00              B02617         228
# 6                B02617 2015-05-17 09:47:00              B02617           7
# 7                B02617 2015-05-17 09:47:00              B02764          74
# 8                B02617 2015-05-17 09:47:00              B02617         249
# 9                B02617 2015-05-17 09:47:00              B02764          22
# 10               B02617 2015-05-17 09:48:00              B02617         263
# ...

# %%
df_uber=df_uber[['Pickup_date','locationID','cab_type']]

# %%
df_uber.head()
# Out:
#           Pickup_date  locationID cab_type
# 0 2015-05-17 09:47:00         141     Uber
# 1 2015-05-17 09:47:00          65     Uber
# 2 2015-05-17 09:47:00         100     Uber
# 3 2015-05-17 09:47:00          80     Uber
# 4 2015-05-17 09:47:00          90     Uber

# %%
df_green_1=pd.read_parquet('data/green_tripdata_2015-01.parquet')
df_green_2=pd.read_parquet('data/green_tripdata_2015-02.parquet')
df_green_3=pd.read_parquet('data/green_tripdata_2015-03.parquet')
df_green_4=pd.read_parquet('data/green_tripdata_2015-04.parquet')
df_green_5=pd.read_parquet('data/green_tripdata_2015-05.parquet')
df_green_6=pd.read_parquet('data/green_tripdata_2015-06.parquet')

frame=[df_green_1,df_green_2,df_green_3,df_green_4,df_green_5,df_green_6]
df_green=pd.concat(frame)

# %%
df_green.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2015-01-01 00:31:10   2015-01-01 00:50:41                  N
# 1         2  2015-01-01 00:01:05   2015-01-01 00:03:30                  N
# 2         2  2015-01-01 00:09:01   2015-01-01 00:33:26                  N
# 3         2  2015-01-01 00:17:34   2015-01-01 00:27:07                  N
# 4         2  2015-01-01 00:32:38   2015-01-01 00:40:32                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           255           234                1           5.88
# 1           1            75            74                1           0.89
# 2           1            43           186                1           5.71
# 3           1            80            36                1           1.89
# 4           1            37            17                1           1.07
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# ...

# %%
df_green=df_green[['lpep_pickup_datetime','PULocationID']]

# %%
df_green['cab_type']='Green'

# %%
df_green.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9896007 entries, 0 to 1638867
# Data columns (total 3 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   lpep_pickup_datetime  datetime64[ns]
#  1   PULocationID          int64
#  2   cab_type              object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 302.0+ MB

# %%
df_green.head()
# Out:
#   lpep_pickup_datetime  PULocationID cab_type
# 0  2015-01-01 00:31:10           255    Green
# 1  2015-01-01 00:01:05            75    Green
# 2  2015-01-01 00:09:01            43    Green
# 3  2015-01-01 00:17:34            80    Green
# 4  2015-01-01 00:32:38            37    Green

# %%
df_uber.head()
# Out:
#           Pickup_date  locationID cab_type
# 0 2015-05-17 09:47:00         141     Uber
# 1 2015-05-17 09:47:00          65     Uber
# 2 2015-05-17 09:47:00         100     Uber
# 3 2015-05-17 09:47:00          80     Uber
# 4 2015-05-17 09:47:00          90     Uber

# %%
df_green.rename(columns={'lpep_pickup_datetime':'Pickup_date','PULocationID':'locationID'},inplace=True)

# %%
frame=[df_green,df_uber]
df_agg=pd.concat(frame)

# %%
df_agg.head()
# Out:
#           Pickup_date  locationID cab_type
# 0 2015-01-01 00:31:10         255    Green
# 1 2015-01-01 00:01:05          75    Green
# 2 2015-01-01 00:09:01          43    Green
# 3 2015-01-01 00:17:34          80    Green
# 4 2015-01-01 00:32:38          37    Green

# %%
df_agg.tail()
# Out:
#                  Pickup_date  locationID cab_type
# 14270474 2015-05-08 15:43:00         186     Uber
# 14270475 2015-05-08 15:43:00         263     Uber
# 14270476 2015-05-08 15:43:00          90     Uber
# 14270477 2015-05-08 15:44:00          45     Uber
# 14270478 2015-05-08 15:44:00         144     Uber

# %%
import datetime

def get_hours(x:pd.Series)->pd.Series:
    x=x.apply(lambda x:x.hour)
    return x

def get_day_of_month(x:pd.Series)->pd.Series:
    x=x.apply(lambda x:x.day)
    return x

def get_day_of_week(x:pd.Series)->pd.Series:
    x=x.apply(lambda x:x.weekday())
    return x

def get_day_of_week_name(x:pd.Series)->pd.Series:
    x=x.apply(lambda x:x.strftime('%A'))
    return x

# %%
df_agg['Hour Of Day']=get_hours(df_agg['Pickup_date'])
df_agg['Month Day Num']=get_day_of_month(df_agg['Pickup_date'])
df_agg['Day Of Week Num']=get_day_of_week(df_agg['Pickup_date'])
df_agg['Day Of Week']=get_day_of_week_name(df_agg['Pickup_date'])

# %%
df_agg.head()
# Out:
#           Pickup_date  locationID cab_type  Hour Of Day  Month Day Num  \
# 0 2015-01-01 00:31:10         255    Green            0              1
# 1 2015-01-01 00:01:05          75    Green            0              1
# 2 2015-01-01 00:09:01          43    Green            0              1
# 3 2015-01-01 00:17:34          80    Green            0              1
# 4 2015-01-01 00:32:38          37    Green            0              1
#
#    Day Of Week Num Day Of Week
# 0                3    Thursday
# 1                3    Thursday
# 2                3    Thursday
# 3                3    Thursday
# 4                3    Thursday

# %%
df_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24166486 entries, 0 to 14270478
# Data columns (total 7 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Pickup_date      datetime64[ns]
#  1   locationID       int64
#  2   cab_type         object
#  3   Hour Of Day      int64
#  4   Month Day Num    int64
#  5   Day Of Week Num  int64
#  6   Day Of Week      object
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 1.4+ GB

# %%
df_agg.to_csv('df_agg.csv')

# %% [markdown]
# ## Introduction
# In August 2013, the New York City Taxi and Limousine Commission (NYCTLC) introduced Green Cabs in the New York City area aimed at residents outside Manhattan with the consideration that Yellow Cabs tend to be low in the area. Green Cabs themselves are designed to be ordered by passengers via telephone or online.
# In May 2011, Uber expanded to the New York City area. Research shows that Uber has replaced rides in Yellow Cabs in downtown NYC and supplemented rides with Green Cabs outside of NYC. As such, Green Cabs have faced fierce competition from Uber since its introduction, with Uber offering lower fares and easier accessibility through its mobile app.
#
# ## Goals
# Analyzing the performance of Green Cabs and Uber Taxi through visual analysis of passenger trips using Green Cabs and Uber Taxi from January to June in 2015 in the New York City area
# Broadly speaking, there are two questions related to the research conducted:
# * How do Green Cabs and Uber rides compare regionally in neighborhoods outside of New York City?
# * Do customer preferences change according to the time of day (night/day or weekend/weekday)?
#
# ## Methodology
# ![image.png](attachment:image.png)
